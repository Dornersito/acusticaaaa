# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import librosa
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from IPython.display import Audio
import pandas as pd
import csv

# %%
client_id = "5e014985ad3b448a9a1941678627bcb4"
client_secret = "45bfe7fe93c14e578a40ac0dad5f63df"
spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret), requests_timeout=10, retries=3)
spotify.trace = True

# %%
df = pd.read_csv("278k_labelled_uri.csv")
df.drop(columns=["Unnamed: 0"], inplace=True)
df.rename(columns={"Unnamed: 0.1": "song_id"}, inplace=True)
df.head()
# Out:
#    song_id  duration (ms)  danceability  energy  loudness  speechiness  \
# 0        0       195000.0         0.611   0.614    -8.815       0.0672
# 1        1       194641.0         0.638   0.781    -6.848       0.0285
# 2        2       217573.0         0.560   0.810    -8.029       0.0872
# 3        3       443478.0         0.525   0.699    -4.571       0.0353
# 4        4       225862.0         0.367   0.771    -5.863       0.1060
#
#    acousticness  instrumentalness  liveness  valence    tempo     spec_rate  \
# 0        0.0169          0.000794    0.7530    0.520  128.050  3.446154e-07
# 1        0.0118          0.009530    0.3490    0.250  122.985  1.464234e-07
# 2        0.0071          0.000008    0.2410    0.247  170.044  4.007850e-07
# 3        0.0178          0.000088    0.0888    0.199   92.011  7.959809e-08
# 4        0.3650          0.000001    0.0965    0.163  115.917  4.693131e-07
#
#    labels                                   uri
# 0       2  spotify:track:3v6sBj3swihU8pXQQHhDZo
# 1       1  spotify:track:7KCWmFdw0TzoJbKtqRRzJO
# 2       1  spotify:track:2CY92qejUrhyPUASawNVRr
# 3       0  spotify:track:11BPfwVbB7vok7KfjBeW4k
# 4       1  spotify:track:3yUJKPsjvThlcQWTS9ttYx

# %%
import pandas as pd
import numpy as np
import requests
import librosa
import csv
import gc
from io import BytesIO
import time
from pathlib import Path

def process_tracks_by_label(df, spotify, tracks_per_label=100):
    dataframe_dict = {
        "song_id": [], "duration (ms)": [], "danceability": [], 
        "energy": [], "loudness": [], "speechiness": [], 
        "acousticness": [], "instrumentalness": [], "liveness": [], 
        "valence": [], "tempo": [], "spec_rate": [], "uri": [], 
        "labels": []
    }
    
    # Crear directorio para mel spectrogramas si no existe
    mel_dir = Path("mel_spectrograms")
    mel_dir.mkdir(exist_ok=True)
    
    for label, grupo in df.groupby('labels'):
        print(f"\n=== Procesando label {label} ===")
        agregados = 0
        
        # Procesar en lotes de 20 canciones para evitar rate limiting
        for i in range(0, len(grupo), 20):
            if agregados >= tracks_per_label:
                break     

            batch = grupo.iloc[i:i+20]
            print(f"Label {label}: Procesando canciones {i} a {i+20}")
            
            for _, row in batch.iterrows():
                if agregados >= tracks_per_label:
                    break
                    
                song_id = row["song_id"]
                uri = row['uri']
                track_id = uri.split(":")[-1]
                
                try:
                    for attempt in range(3):
                        try:
                            track_info = spotify.track(track_id)
                            break
                        except Exception as e:
                            if "rate limit" in str(e).lower():
                                wait_time = 5 * (attempt + 1)
                                print(f"Rate limit alcanzado. Esperando {wait_time} segundos...")
                                time.sleep(wait_time)
                            else:
                                raise e
                    
                    if "preview_url" in track_info and track_info["preview_url"]:
                        # Procesar mel spectrogram
                        mel_file = mel_dir / f"{song_id}.csv"
                        
                        if not mel_file.exists():  # Evitar reprocesar si ya existe
                            try:
                                preview_url = track_info['preview_url']
                                audio_content = requests.get(preview_url).content
                                y, sr = librosa.load(BytesIO(audio_content), sr=None, duration=5.0)
                                
                                mel_spect = librosa.feature.melspectrogram(y=y, sr=sr)
                                mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)
                                mel_vector = mel_spect_db.ravel().tolist()
                                
                                with open(mel_file, 'w', newline='') as csvfile:
                                    writer = csv.writer(csvfile)
                                    writer.writerow([song_id] + mel_vector)
                                
                                # Limpiar memoria
                                del y, mel_spect, mel_spect_db, mel_vector
                                gc.collect()
                                
                                # Agregar datos al diccionario
                                for key in dataframe_dict.keys():
                                    dataframe_dict[key].append(row[key])

                            except Exception as e:
                                print(f"Error procesando mel spectrogram para {song_id}: {e}")
                                continue

                        agregados += 1
                        print(f"Label {label}: {agregados}/{tracks_per_label} canciones procesadas")
                
                except Exception as e:
                    print(f"Error procesando track {song_id}: {e}")
                    continue
            
            # Esperar entre lotes para evitar rate limiting
            if agregados < tracks_per_label:
                print("Esperando 1 segundo entre lotes...")
                time.sleep(1)
        
        print(f"Completado label {label}: {agregados} canciones procesadas")
    
    return pd.DataFrame(dataframe_dict)

try:
    result_df = process_tracks_by_label(df, spotify, tracks_per_label=100)
    print("\nProceso completado!")
    print("Forma del DataFrame resultante:", result_df.shape)
    print("\nDistribución de labels:")
    print(result_df['labels'].value_counts())
    
    # Guardar resultado
    result_df.to_csv('processed_tracks.csv', index=False)
    print("\nResultados guardados en 'processed_tracks.csv'")
    
except Exception as e:
    print(f"Error en el proceso principal: {e}")
# Out:
# === Procesando label 0 ===
# Label 0: Procesando canciones 0 a 20
# Label 0: 1/100 canciones procesadas
# Label 0: 2/100 canciones procesadas
# Label 0: 3/100 canciones procesadas
# Label 0: 4/100 canciones procesadas
# Label 0: 5/100 canciones procesadas
# Label 0: 6/100 canciones procesadas
# Label 0: 7/100 canciones procesadas
# Label 0: 8/100 canciones procesadas
# Label 0: 9/100 canciones procesadas
# Label 0: 10/100 canciones procesadas
# Label 0: 11/100 canciones procesadas
# Label 0: 12/100 canciones procesadas
# Label 0: 13/100 canciones procesadas
# Label 0: 14/100 canciones procesadas
# Label 0: 15/100 canciones procesadas
# Label 0: 16/100 canciones procesadas
# Label 0: 17/100 canciones procesadas
# Label 0: 18/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 0: Procesando canciones 20 a 40
# Label 0: 19/100 canciones procesadas
# Label 0: 20/100 canciones procesadas
# Label 0: 21/100 canciones procesadas
# Label 0: 22/100 canciones procesadas
# Label 0: 23/100 canciones procesadas
# Label 0: 24/100 canciones procesadas
# Label 0: 25/100 canciones procesadas
# Label 0: 26/100 canciones procesadas
# Label 0: 27/100 canciones procesadas
# Label 0: 28/100 canciones procesadas
# Label 0: 29/100 canciones procesadas
# Label 0: 30/100 canciones procesadas
# Label 0: 31/100 canciones procesadas
# Label 0: 32/100 canciones procesadas
# Label 0: 33/100 canciones procesadas
# Label 0: 34/100 canciones procesadas
# Label 0: 35/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 0: Procesando canciones 40 a 60
# Label 0: 36/100 canciones procesadas
# Label 0: 37/100 canciones procesadas
# Label 0: 38/100 canciones procesadas
# Label 0: 39/100 canciones procesadas
# Label 0: 40/100 canciones procesadas
# Label 0: 41/100 canciones procesadas
# Label 0: 42/100 canciones procesadas
# Label 0: 43/100 canciones procesadas
# Label 0: 44/100 canciones procesadas
# Label 0: 45/100 canciones procesadas
# Label 0: 46/100 canciones procesadas
# Label 0: 47/100 canciones procesadas
# Label 0: 48/100 canciones procesadas
# Label 0: 49/100 canciones procesadas
# Label 0: 50/100 canciones procesadas
# Label 0: 51/100 canciones procesadas
# Label 0: 52/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 0: Procesando canciones 60 a 80
# Label 0: 53/100 canciones procesadas
# Label 0: 54/100 canciones procesadas
# Label 0: 55/100 canciones procesadas
# Label 0: 56/100 canciones procesadas
# Label 0: 57/100 canciones procesadas
# Label 0: 58/100 canciones procesadas
# Label 0: 59/100 canciones procesadas
# Label 0: 60/100 canciones procesadas
# Label 0: 61/100 canciones procesadas
# Label 0: 62/100 canciones procesadas
# Label 0: 63/100 canciones procesadas
# Label 0: 64/100 canciones procesadas
# Label 0: 65/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 0: Procesando canciones 80 a 100
# Label 0: 66/100 canciones procesadas
# Label 0: 67/100 canciones procesadas
# Label 0: 68/100 canciones procesadas
# Label 0: 69/100 canciones procesadas
# Label 0: 70/100 canciones procesadas
# Label 0: 71/100 canciones procesadas
# Label 0: 72/100 canciones procesadas
# Label 0: 73/100 canciones procesadas
# Label 0: 74/100 canciones procesadas
# Label 0: 75/100 canciones procesadas
# Label 0: 76/100 canciones procesadas
# Label 0: 77/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 0: Procesando canciones 100 a 120
# Label 0: 78/100 canciones procesadas
# Label 0: 79/100 canciones procesadas
# Label 0: 80/100 canciones procesadas
# Label 0: 81/100 canciones procesadas
# Label 0: 82/100 canciones procesadas
# Label 0: 83/100 canciones procesadas
# Label 0: 84/100 canciones procesadas
# Label 0: 85/100 canciones procesadas
# Label 0: 86/100 canciones procesadas
# Label 0: 87/100 canciones procesadas
# Label 0: 88/100 canciones procesadas
# Label 0: 89/100 canciones procesadas
# Label 0: 90/100 canciones procesadas
# Label 0: 91/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 0: Procesando canciones 120 a 140
# Label 0: 92/100 canciones procesadas
# Label 0: 93/100 canciones procesadas
# Label 0: 94/100 canciones procesadas
# Label 0: 95/100 canciones procesadas
# Label 0: 96/100 canciones procesadas
# Label 0: 97/100 canciones procesadas
# Label 0: 98/100 canciones procesadas
# Label 0: 99/100 canciones procesadas
# Label 0: 100/100 canciones procesadas
# Completado label 0: 100 canciones procesadas
#
# === Procesando label 1 ===
# Label 1: Procesando canciones 0 a 20
# Label 1: 1/100 canciones procesadas
# Label 1: 2/100 canciones procesadas
# Label 1: 3/100 canciones procesadas
# Label 1: 4/100 canciones procesadas
# Label 1: 5/100 canciones procesadas
# Label 1: 6/100 canciones procesadas
# Label 1: 7/100 canciones procesadas
# Label 1: 8/100 canciones procesadas
# Label 1: 9/100 canciones procesadas
# Label 1: 10/100 canciones procesadas
# Label 1: 11/100 canciones procesadas
# Label 1: 12/100 canciones procesadas
# Label 1: 13/100 canciones procesadas
# Label 1: 14/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 1: Procesando canciones 20 a 40
# Label 1: 15/100 canciones procesadas
# Label 1: 16/100 canciones procesadas
# Label 1: 17/100 canciones procesadas
# Label 1: 18/100 canciones procesadas
# Label 1: 19/100 canciones procesadas
# Label 1: 20/100 canciones procesadas
# Label 1: 21/100 canciones procesadas
# Label 1: 22/100 canciones procesadas
# Label 1: 23/100 canciones procesadas
# Label 1: 24/100 canciones procesadas
# Label 1: 25/100 canciones procesadas
# Label 1: 26/100 canciones procesadas
# Label 1: 27/100 canciones procesadas
# Label 1: 28/100 canciones procesadas
# Label 1: 29/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 1: Procesando canciones 40 a 60
# Label 1: 30/100 canciones procesadas
# Label 1: 31/100 canciones procesadas
# Label 1: 32/100 canciones procesadas
# Label 1: 33/100 canciones procesadas
# Label 1: 34/100 canciones procesadas
# Label 1: 35/100 canciones procesadas
# Label 1: 36/100 canciones procesadas
# Label 1: 37/100 canciones procesadas
# Label 1: 38/100 canciones procesadas
# Label 1: 39/100 canciones procesadas
# Label 1: 40/100 canciones procesadas
# Label 1: 41/100 canciones procesadas
# Label 1: 42/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 1: Procesando canciones 60 a 80
# Label 1: 43/100 canciones procesadas
# Label 1: 44/100 canciones procesadas
# Label 1: 45/100 canciones procesadas
# Label 1: 46/100 canciones procesadas
# Label 1: 47/100 canciones procesadas
# Label 1: 48/100 canciones procesadas
# Label 1: 49/100 canciones procesadas
# Label 1: 50/100 canciones procesadas
# Label 1: 51/100 canciones procesadas
# Label 1: 52/100 canciones procesadas
# Label 1: 53/100 canciones procesadas
# Label 1: 54/100 canciones procesadas
# Label 1: 55/100 canciones procesadas
# Label 1: 56/100 canciones procesadas
# Label 1: 57/100 canciones procesadas
# Label 1: 58/100 canciones procesadas
# Label 1: 59/100 canciones procesadas
# Label 1: 60/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 1: Procesando canciones 80 a 100
# Label 1: 61/100 canciones procesadas
# Label 1: 62/100 canciones procesadas
# Label 1: 63/100 canciones procesadas
# Label 1: 64/100 canciones procesadas
# Label 1: 65/100 canciones procesadas
# Label 1: 66/100 canciones procesadas
# Label 1: 67/100 canciones procesadas
# Label 1: 68/100 canciones procesadas
# Label 1: 69/100 canciones procesadas
# Label 1: 70/100 canciones procesadas
# Label 1: 71/100 canciones procesadas
# Label 1: 72/100 canciones procesadas
# Label 1: 73/100 canciones procesadas
# Label 1: 74/100 canciones procesadas
# Label 1: 75/100 canciones procesadas
# Label 1: 76/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 1: Procesando canciones 100 a 120
# Label 1: 77/100 canciones procesadas
# Label 1: 78/100 canciones procesadas
# Label 1: 79/100 canciones procesadas
# Label 1: 80/100 canciones procesadas
# Label 1: 81/100 canciones procesadas
# Label 1: 82/100 canciones procesadas
# Label 1: 83/100 canciones procesadas
# Label 1: 84/100 canciones procesadas
# Label 1: 85/100 canciones procesadas
# Label 1: 86/100 canciones procesadas
# Label 1: 87/100 canciones procesadas
# Label 1: 88/100 canciones procesadas
# Label 1: 89/100 canciones procesadas
# Label 1: 90/100 canciones procesadas
# Label 1: 91/100 canciones procesadas
# Label 1: 92/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 1: Procesando canciones 120 a 140
# Label 1: 93/100 canciones procesadas
# Label 1: 94/100 canciones procesadas
# Label 1: 95/100 canciones procesadas
# Label 1: 96/100 canciones procesadas
# Label 1: 97/100 canciones procesadas
# Label 1: 98/100 canciones procesadas
# Label 1: 99/100 canciones procesadas
# Label 1: 100/100 canciones procesadas
# Completado label 1: 100 canciones procesadas
#
# === Procesando label 2 ===
# Label 2: Procesando canciones 0 a 20
# Label 2: 1/100 canciones procesadas
# Label 2: 2/100 canciones procesadas
# Label 2: 3/100 canciones procesadas
# Label 2: 4/100 canciones procesadas
# Label 2: 5/100 canciones procesadas
# Label 2: 6/100 canciones procesadas
# Label 2: 7/100 canciones procesadas
# Label 2: 8/100 canciones procesadas
# Label 2: 9/100 canciones procesadas
# Label 2: 10/100 canciones procesadas
# Label 2: 11/100 canciones procesadas
# Label 2: 12/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 2: Procesando canciones 20 a 40
# Label 2: 13/100 canciones procesadas
# Label 2: 14/100 canciones procesadas
# Label 2: 15/100 canciones procesadas
# Label 2: 16/100 canciones procesadas
# Label 2: 17/100 canciones procesadas
# Label 2: 18/100 canciones procesadas
# Label 2: 19/100 canciones procesadas
# Label 2: 20/100 canciones procesadas
# Label 2: 21/100 canciones procesadas
# Label 2: 22/100 canciones procesadas
# Label 2: 23/100 canciones procesadas
# Label 2: 24/100 canciones procesadas
# Label 2: 25/100 canciones procesadas
# Label 2: 26/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 2: Procesando canciones 40 a 60
# Label 2: 27/100 canciones procesadas
# Label 2: 28/100 canciones procesadas
# Label 2: 29/100 canciones procesadas
# Label 2: 30/100 canciones procesadas
# Label 2: 31/100 canciones procesadas
# Label 2: 32/100 canciones procesadas
# Label 2: 33/100 canciones procesadas
# Label 2: 34/100 canciones procesadas
# Label 2: 35/100 canciones procesadas
# Label 2: 36/100 canciones procesadas
# Label 2: 37/100 canciones procesadas
# Label 2: 38/100 canciones procesadas
# Label 2: 39/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 2: Procesando canciones 60 a 80
# Label 2: 40/100 canciones procesadas
# Label 2: 41/100 canciones procesadas
# Label 2: 42/100 canciones procesadas
# Label 2: 43/100 canciones procesadas
# Label 2: 44/100 canciones procesadas
# Label 2: 45/100 canciones procesadas
# Label 2: 46/100 canciones procesadas
# Label 2: 47/100 canciones procesadas
# Label 2: 48/100 canciones procesadas
# Label 2: 49/100 canciones procesadas
# Label 2: 50/100 canciones procesadas
# Label 2: 51/100 canciones procesadas
# Label 2: 52/100 canciones procesadas
# Label 2: 53/100 canciones procesadas
# Label 2: 54/100 canciones procesadas
# Label 2: 55/100 canciones procesadas
# Label 2: 56/100 canciones procesadas
# Label 2: 57/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 2: Procesando canciones 80 a 100
# Label 2: 58/100 canciones procesadas
# Label 2: 59/100 canciones procesadas
# Label 2: 60/100 canciones procesadas
# Label 2: 61/100 canciones procesadas
# Label 2: 62/100 canciones procesadas
# Label 2: 63/100 canciones procesadas
# Label 2: 64/100 canciones procesadas
# Label 2: 65/100 canciones procesadas
# Label 2: 66/100 canciones procesadas
# Label 2: 67/100 canciones procesadas
# Label 2: 68/100 canciones procesadas
# Label 2: 69/100 canciones procesadas
# Label 2: 70/100 canciones procesadas
# Label 2: 71/100 canciones procesadas
# Label 2: 72/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 2: Procesando canciones 100 a 120
# Label 2: 73/100 canciones procesadas
# Label 2: 74/100 canciones procesadas
# Label 2: 75/100 canciones procesadas
# Label 2: 76/100 canciones procesadas
# Label 2: 77/100 canciones procesadas
# Label 2: 78/100 canciones procesadas
# Label 2: 79/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 2: Procesando canciones 120 a 140
# Label 2: 80/100 canciones procesadas
# Label 2: 81/100 canciones procesadas
# Label 2: 82/100 canciones procesadas
# Label 2: 83/100 canciones procesadas
# Label 2: 84/100 canciones procesadas
# Label 2: 85/100 canciones procesadas
# Label 2: 86/100 canciones procesadas
# Label 2: 87/100 canciones procesadas
# Label 2: 88/100 canciones procesadas
# Label 2: 89/100 canciones procesadas
# Label 2: 90/100 canciones procesadas
# Label 2: 91/100 canciones procesadas
# Label 2: 92/100 canciones procesadas
# Label 2: 93/100 canciones procesadas
# Label 2: 94/100 canciones procesadas
# Label 2: 95/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 2: Procesando canciones 140 a 160
# Label 2: 96/100 canciones procesadas
# Label 2: 97/100 canciones procesadas
# Label 2: 98/100 canciones procesadas
# Label 2: 99/100 canciones procesadas
# Label 2: 100/100 canciones procesadas
# Completado label 2: 100 canciones procesadas
#
# === Procesando label 3 ===
# Label 3: Procesando canciones 0 a 20
# Label 3: 1/100 canciones procesadas
# Label 3: 2/100 canciones procesadas
# Label 3: 3/100 canciones procesadas
# Label 3: 4/100 canciones procesadas
# Label 3: 5/100 canciones procesadas
# Label 3: 6/100 canciones procesadas
# Label 3: 7/100 canciones procesadas
# Label 3: 8/100 canciones procesadas
# Label 3: 9/100 canciones procesadas
# Label 3: 10/100 canciones procesadas
# Label 3: 11/100 canciones procesadas
# Label 3: 12/100 canciones procesadas
# Label 3: 13/100 canciones procesadas
# Label 3: 14/100 canciones procesadas
# Label 3: 15/100 canciones procesadas
# Label 3: 16/100 canciones procesadas
# Label 3: 17/100 canciones procesadas
# Label 3: 18/100 canciones procesadas
# Label 3: 19/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 3: Procesando canciones 20 a 40
# Label 3: 20/100 canciones procesadas
# Label 3: 21/100 canciones procesadas
# Label 3: 22/100 canciones procesadas
# Label 3: 23/100 canciones procesadas
# Label 3: 24/100 canciones procesadas
# Label 3: 25/100 canciones procesadas
# Label 3: 26/100 canciones procesadas
# Label 3: 27/100 canciones procesadas
# Label 3: 28/100 canciones procesadas
# Label 3: 29/100 canciones procesadas
# Label 3: 30/100 canciones procesadas
# Label 3: 31/100 canciones procesadas
# Label 3: 32/100 canciones procesadas
# Label 3: 33/100 canciones procesadas
# Label 3: 34/100 canciones procesadas
# Label 3: 35/100 canciones procesadas
# Label 3: 36/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 3: Procesando canciones 40 a 60
# Label 3: 37/100 canciones procesadas
# Label 3: 38/100 canciones procesadas
# Label 3: 39/100 canciones procesadas
# Label 3: 40/100 canciones procesadas
# Label 3: 41/100 canciones procesadas
# Label 3: 42/100 canciones procesadas
# Label 3: 43/100 canciones procesadas
# Label 3: 44/100 canciones procesadas
# Label 3: 45/100 canciones procesadas
# Label 3: 46/100 canciones procesadas
# Label 3: 47/100 canciones procesadas
# Label 3: 48/100 canciones procesadas
# Label 3: 49/100 canciones procesadas
# Label 3: 50/100 canciones procesadas
# Label 3: 51/100 canciones procesadas
# Label 3: 52/100 canciones procesadas
# Label 3: 53/100 canciones procesadas
# Label 3: 54/100 canciones procesadas
# Label 3: 55/100 canciones procesadas
# Label 3: 56/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 3: Procesando canciones 60 a 80
# Label 3: 57/100 canciones procesadas
# Label 3: 58/100 canciones procesadas
# Label 3: 59/100 canciones procesadas
# Label 3: 60/100 canciones procesadas
# Label 3: 61/100 canciones procesadas
# Label 3: 62/100 canciones procesadas
# Label 3: 63/100 canciones procesadas
# Label 3: 64/100 canciones procesadas
# Label 3: 65/100 canciones procesadas
# Label 3: 66/100 canciones procesadas
# Label 3: 67/100 canciones procesadas
# Label 3: 68/100 canciones procesadas
# Label 3: 69/100 canciones procesadas
# Label 3: 70/100 canciones procesadas
# Label 3: 71/100 canciones procesadas
# Label 3: 72/100 canciones procesadas
# Label 3: 73/100 canciones procesadas
# Label 3: 74/100 canciones procesadas
# Label 3: 75/100 canciones procesadas
# Label 3: 76/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 3: Procesando canciones 80 a 100
# Label 3: 77/100 canciones procesadas
# Label 3: 78/100 canciones procesadas
# Label 3: 79/100 canciones procesadas
# Label 3: 80/100 canciones procesadas
# Label 3: 81/100 canciones procesadas
# Label 3: 82/100 canciones procesadas
# Label 3: 83/100 canciones procesadas
# Label 3: 84/100 canciones procesadas
# Label 3: 85/100 canciones procesadas
# Label 3: 86/100 canciones procesadas
# Label 3: 87/100 canciones procesadas
# Label 3: 88/100 canciones procesadas
# Label 3: 89/100 canciones procesadas
# Label 3: 90/100 canciones procesadas
# Label 3: 91/100 canciones procesadas
# Label 3: 92/100 canciones procesadas
# Label 3: 93/100 canciones procesadas
# Label 3: 94/100 canciones procesadas
# Label 3: 95/100 canciones procesadas
# Label 3: 96/100 canciones procesadas
# Esperando 1 segundo entre lotes...
# Label 3: Procesando canciones 100 a 120
# Label 3: 97/100 canciones procesadas
# Label 3: 98/100 canciones procesadas
# Label 3: 99/100 canciones procesadas
# Label 3: 100/100 canciones procesadas
# Completado label 3: 100 canciones procesadas
#
# Proceso completado!
# Forma del DataFrame resultante: (400, 14)
#
# Distribución de labels:
# labels
# 0    100
# 1    100
# 2    100
# 3    100
# Name: count, dtype: int64
#
# Resultados guardados en 'processed_tracks.csv'

# %%
import pandas as pd
import os

folder_path = "./mel_spectrograms"

headers = ["song_id"] + [f"t{t}_b{b}" for t in range(431) for b in range(128)]

mel_spectrograms_df = pd.DataFrame(columns=headers)

for (i, filename) in enumerate(os.listdir(folder_path)):
    print(f"{i}/400")
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path, header=None)
        df.columns = headers
        mel_spectrograms_df = pd.concat([mel_spectrograms_df, df], ignore_index=True)

mel_spectrograms_df.to_pickle("mel_spectrograms_df.pkl")

mel_spectrograms_df.head()
# Out:
# 0/400
# /tmp/ipykernel_35986/3547614708.py:16: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   mel_spectrograms_df = pd.concat([mel_spectrograms_df, df], ignore_index=True)
# 1/400
# 2/400
# 3/400
# 4/400
# 5/400
# 6/400
# 7/400
# 8/400
# 9/400
# 10/400
# 11/400
# 12/400
# 13/400
# 14/400
# 15/400
# 16/400
# 17/400
# 18/400
# 19/400
# 20/400
# 21/400
# 22/400
# 23/400
# 24/400
# 25/400
# 26/400
# 27/400
# 28/400
# 29/400
# 30/400
# 31/400
# 32/400
# 33/400
# 34/400
# 35/400
# 36/400
# 37/400
# 38/400
# 39/400
# 40/400
# 41/400
# 42/400
# 43/400
# 44/400
# 45/400
# 46/400
# 47/400
# 48/400
# 49/400
# 50/400
# 51/400
# 52/400
# 53/400
# 54/400
# 55/400
# 56/400
# 57/400
# 58/400
# 59/400
# 60/400
# 61/400
# 62/400
# 63/400
# 64/400
# 65/400
# 66/400
# 67/400
# 68/400
# 69/400
# 70/400
# 71/400
# 72/400
# 73/400
# 74/400
# 75/400
# 76/400
# 77/400
# 78/400
# 79/400
# 80/400
# 81/400
# 82/400
# 83/400
# 84/400
# 85/400
# 86/400
# 87/400
# 88/400
# 89/400
# 90/400
# 91/400
# 92/400
# 93/400
# 94/400
# 95/400
# 96/400
# 97/400
# 98/400
# 99/400
# 100/400
# 101/400
# 102/400
# 103/400
# 104/400
# 105/400
# 106/400
# 107/400
# 108/400
# 109/400
# 110/400
# 111/400
# 112/400
# 113/400
# 114/400
# 115/400
# 116/400
# 117/400
# 118/400
# 119/400
# 120/400
# 121/400
# 122/400
# 123/400
# 124/400
# 125/400
# 126/400
# 127/400
# 128/400
# 129/400
# 130/400
# 131/400
# 132/400
# 133/400
# 134/400
# 135/400
# 136/400
# 137/400
# 138/400
# 139/400
# 140/400
# 141/400
# 142/400
# 143/400
# 144/400
# 145/400
# 146/400
# 147/400
# 148/400
# 149/400
# 150/400
# 151/400
# 152/400
# 153/400
# 154/400
# 155/400
# 156/400
# 157/400
# 158/400
# 159/400
# 160/400
# 161/400
# 162/400
# 163/400
# 164/400
# 165/400
# 166/400
# 167/400
# 168/400
# 169/400
# 170/400
# 171/400
# 172/400
# 173/400
# 174/400
# 175/400
# 176/400
# 177/400
# 178/400
# 179/400
# 180/400
# 181/400
# 182/400
# 183/400
# 184/400
# 185/400
# 186/400
# 187/400
# 188/400
# 189/400
# 190/400
# 191/400
# 192/400
# 193/400
# 194/400
# 195/400
# 196/400
# 197/400
# 198/400
# 199/400
# 200/400
# 201/400
# 202/400
# 203/400
# 204/400
# 205/400
# 206/400
# 207/400
# 208/400
# 209/400
# 210/400
# 211/400
# 212/400
# 213/400
# 214/400
# 215/400
# 216/400
# 217/400
# 218/400
# 219/400
# 220/400
# 221/400
# 222/400
# 223/400
# 224/400
# 225/400
# 226/400
# 227/400
# 228/400
# 229/400
# 230/400
# 231/400
# 232/400
# 233/400
# 234/400
# 235/400
# 236/400
# 237/400
# 238/400
# 239/400
# 240/400
# 241/400
# 242/400
# 243/400
# 244/400
# 245/400
# 246/400
# 247/400
# 248/400
# 249/400
# 250/400
# 251/400
# 252/400
# 253/400
# 254/400
# 255/400
# 256/400
# 257/400
# 258/400
# 259/400
# 260/400
# 261/400
# 262/400
# 263/400
# 264/400
# 265/400
# 266/400
# 267/400
# 268/400
# 269/400
# 270/400
# 271/400
# 272/400
# 273/400
# 274/400
# 275/400
# 276/400
# 277/400
# 278/400
# 279/400
# 280/400
# 281/400
# 282/400
# 283/400
# 284/400
# 285/400
# 286/400
# 287/400
# 288/400
# 289/400
# 290/400
# 291/400
# 292/400
# 293/400
# 294/400
# 295/400
# 296/400
# 297/400
# 298/400
# 299/400
# 300/400
# 301/400
# 302/400
# 303/400
# 304/400
# 305/400
# 306/400
# 307/400
# 308/400
# 309/400
# 310/400
# 311/400
# 312/400
# 313/400
# 314/400
# 315/400
# 316/400
# 317/400
# 318/400
# 319/400
# 320/400
# 321/400
# 322/400
# 323/400
# 324/400
# 325/400
# 326/400
# 327/400
# 328/400
# 329/400
# 330/400
# 331/400
# 332/400
# 333/400
# 334/400
# 335/400
# 336/400
# 337/400
# 338/400
# 339/400
# 340/400
# 341/400
# 342/400
# 343/400
# 344/400
# 345/400
# 346/400
# 347/400
# 348/400
# 349/400
# 350/400
# 351/400
# 352/400
# 353/400
# 354/400
# 355/400
# 356/400
# 357/400
# 358/400
# 359/400
# 360/400
# 361/400
# 362/400
# 363/400
# 364/400
# 365/400
# 366/400
# 367/400
# 368/400
# 369/400
# 370/400
# 371/400
# 372/400
# 373/400
# 374/400
# 375/400
# 376/400
# 377/400
# 378/400
# 379/400
# 380/400
# 381/400
# 382/400
# 383/400
# 384/400
# 385/400
# 386/400
# 387/400
# 388/400
# 389/400
# 390/400
# 391/400
# 392/400
# 393/400
# 394/400
# 395/400
# 396/400
# 397/400
# 398/400
# 399/400
#   song_id      t0_b0      t0_b1      t0_b2      t0_b3      t0_b4      t0_b5  \
# 0     561 -28.449587 -20.357433 -16.270924 -16.019396 -17.589495 -16.149189
# 1     587 -28.257311 -28.569427 -24.319679 -25.002903 -31.400566 -31.267591
# 2     137 -32.398590 -24.398623 -12.331869  -8.607775  -8.463150 -11.070618
# 3      70 -19.587574 -11.403679 -10.102903 -14.255501 -16.495501 -13.532471
# 4      87 -30.482355 -23.153172 -20.124125 -18.806267 -20.171616 -20.383968
#
#        t0_b6      t0_b7      t0_b8  ...  t430_b118  t430_b119  t430_b120  \
# 0 -16.023872 -16.183380 -15.709162  ...      -80.0      -80.0      -80.0
# 1 -30.247046 -29.865032 -26.255615  ...      -80.0      -80.0      -80.0
# 2  -4.962997  -2.811954  -4.763077  ...      -80.0      -80.0      -80.0
# 3 -14.102993 -16.697994 -20.785107  ...      -80.0      -80.0      -80.0
# 4 -21.594028 -20.616934 -19.691050  ...      -80.0      -80.0      -80.0
#
#    t430_b121  t430_b122  t430_b123  t430_b124  t430_b125  t430_b126  t430_b127
# 0      -80.0      -80.0      -80.0      -80.0      -80.0      -80.0 -70.315796
# 1      -80.0      -80.0      -80.0      -80.0      -80.0      -80.0 -69.622780
# 2      -80.0      -80.0      -80.0      -80.0      -80.0      -80.0 -78.528778
# 3      -80.0      -80.0      -80.0      -80.0      -80.0      -80.0 -70.632492
# 4      -80.0      -80.0      -80.0      -80.0      -80.0      -80.0 -68.306915
#
# [5 rows x 55169 columns]

# %%
df = pd.read_csv("processed_tracks.csv")
df = df.set_index("song_id", drop=True)
df.head()
# Out:
#          duration (ms)  danceability  energy  loudness  speechiness  \
# song_id
# 3             443478.0         0.525   0.699    -4.571       0.0353
# 8             216187.0         0.516   0.692    -4.842       0.0279
# 9             232333.0         0.548   0.509    -7.937       0.0288
# 28            197246.0         0.787   0.462    -7.985       0.0908
# 31            253869.0         0.567   0.542    -6.640       0.0309
#
#          acousticness  instrumentalness  liveness  valence    tempo  \
# song_id
# 3              0.0178          0.000088    0.0888    0.199   92.011
# 8              0.0875          0.009300    0.0900    0.181   83.571
# 9              0.2610          0.702000    0.0790    0.484   78.974
# 28             0.7240          0.000187    0.1020    0.554   86.994
# 31             0.3090          0.000342    0.0734    0.229  125.160
#
#             spec_rate                                   uri  labels
# song_id
# 3        7.959809e-08  spotify:track:11BPfwVbB7vok7KfjBeW4k       0
# 8        1.290549e-07  spotify:track:6TwrBbgTaB5gpl06YQoRKy       0
# 9        1.239600e-07  spotify:track:5SDEirHg6Y8fCYuKMnAaC5       0
# 28       4.603389e-07  spotify:track:0kJUHCpOr6CFU15kEKAgVF       0
# 31       1.217163e-07  spotify:track:1zZIVe9x0JhdhpuQjLTjIM       0

# %%
mel_spectrograms_df = mel_spectrograms_df.set_index("song_id", drop=True)
mel_spectrograms_df.head()
# Out:
#              t0_b0      t0_b1      t0_b2      t0_b3      t0_b4      t0_b5  \
# song_id
# 561     -28.449587 -20.357433 -16.270924 -16.019396 -17.589495 -16.149189
# 587     -28.257311 -28.569427 -24.319679 -25.002903 -31.400566 -31.267591
# 137     -32.398590 -24.398623 -12.331869  -8.607775  -8.463150 -11.070618
# 70      -19.587574 -11.403679 -10.102903 -14.255501 -16.495501 -13.532471
# 87      -30.482355 -23.153172 -20.124125 -18.806267 -20.171616 -20.383968
#
#              t0_b6      t0_b7      t0_b8      t0_b9  ...  t430_b118  \
# song_id                                              ...
# 561     -16.023872 -16.183380 -15.709162 -16.888853  ...      -80.0
# 587     -30.247046 -29.865032 -26.255615 -34.355835  ...      -80.0
# 137      -4.962997  -2.811954  -4.763077 -11.053829  ...      -80.0
# 70      -14.102993 -16.697994 -20.785107 -23.791050  ...      -80.0
# 87      -21.594028 -20.616934 -19.691050 -22.387667  ...      -80.0
#
#          t430_b119  t430_b120  t430_b121  t430_b122  t430_b123  t430_b124  \
# song_id
# 561          -80.0      -80.0      -80.0      -80.0      -80.0      -80.0
# 587          -80.0      -80.0      -80.0      -80.0      -80.0      -80.0
# 137          -80.0      -80.0      -80.0      -80.0      -80.0      -80.0
# 70           -80.0      -80.0      -80.0      -80.0      -80.0      -80.0
# 87           -80.0      -80.0      -80.0      -80.0      -80.0      -80.0
#
#          t430_b125  t430_b126  t430_b127
# song_id
# 561          -80.0      -80.0 -70.315796
# 587          -80.0      -80.0 -69.622780
# 137          -80.0      -80.0 -78.528778
# 70           -80.0      -80.0 -70.632492
# 87           -80.0      -80.0 -68.306915
#
# [5 rows x 55168 columns]

# %%
df_final = pd.concat([df, mel_spectrograms_df], axis=1)
df.shape
# Out:
# (400, 13)

# %%
df_final.head()
# Out:
#          duration (ms)  danceability  energy  loudness  speechiness  \
# song_id
# 3             443478.0         0.525   0.699    -4.571       0.0353
# 8             216187.0         0.516   0.692    -4.842       0.0279
# 9             232333.0         0.548   0.509    -7.937       0.0288
# 28            197246.0         0.787   0.462    -7.985       0.0908
# 31            253869.0         0.567   0.542    -6.640       0.0309
#
#          acousticness  instrumentalness  liveness  valence    tempo  ...  \
# song_id                                                              ...
# 3              0.0178          0.000088    0.0888    0.199   92.011  ...
# 8              0.0875          0.009300    0.0900    0.181   83.571  ...
# 9              0.2610          0.702000    0.0790    0.484   78.974  ...
# 28             0.7240          0.000187    0.1020    0.554   86.994  ...
# 31             0.3090          0.000342    0.0734    0.229  125.160  ...
#
#          t430_b118 t430_b119  t430_b120  t430_b121  t430_b122  t430_b123  \
# song_id
# 3            -80.0     -80.0      -80.0      -80.0      -80.0      -80.0
# 8            -80.0     -80.0      -80.0      -80.0      -80.0      -80.0
# 9            -80.0     -80.0      -80.0      -80.0      -80.0      -80.0
# 28           -80.0     -80.0      -80.0      -80.0      -80.0      -80.0
# 31           -80.0     -80.0      -80.0      -80.0      -80.0      -80.0
#
#          t430_b124  t430_b125  t430_b126  t430_b127
# song_id
# 3            -80.0      -80.0      -80.0 -70.186569
# 8            -80.0      -80.0      -80.0 -62.771309
# 9            -80.0      -80.0      -80.0 -78.874359
# 28           -80.0      -80.0      -80.0 -65.996414
# 31           -80.0      -80.0      -80.0 -72.233246
#
# [5 rows x 55181 columns]

# %%
df_final.to_pickle("data_with_mel.pkl")
